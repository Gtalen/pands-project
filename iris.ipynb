# %% [markdown]
# # Exploratory  Data Analysis on the Iris Dataset Using Python
# ## By Ebelechukwu Chidimma Igwagu
# ***

# %% [markdown]
# ## Overview of the Iris data set
# The [Fisher’s Iris dataset](https://archive.ics.uci.edu/dataset/53/iris) contains measured attributes on 33 different species of iris flower. Every row represents an instance of an iris plant. The dataset is made of 150 rows comprising 50 species each of setosa, versicolor, and virginica iris flower. The measured attributes in centimeters were petal length, petal width, sepal length and sepal width. The credit for the original data source was attributed to [Edgar Anderson](https://en.wikipedia.org/wiki/Edgar_Anderson).

# %%
#images

# %% [markdown]
# ## Project Aim
# - Utilized python in exploratory data analysis of the iris dataset to provide meaningful insights.
# - Determine if Iris flowers can be classified based on the measured features.

# %% [markdown]
# ## Prerequisites
# The analysis was started off by importing the necessary libraries needed for data analysis, exploration, manipulation and visualization.
# Pandas was used for data manipulation, Matplotlib and seaborn was used for data visualization.

# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
# importing python warning module
import warnings
sns.set_theme()            #setting seaborn as default style for plots when using matplotlib

# %% [markdown]
# ## Loading the dataset
# The iris dataset was loaded from [here](https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv) using pandas and assigned to the variable "iris_data".

# %%
# Importing the iris dataset from the web to the variable iris
iris_data = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Data Exploration
# To get a quick overview of the dataset, the data head and tail functions were used to view the first and last five rows in the dataset respectively.

# %%
# Viewing the first 5 rows of the dataset
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Viewing the last 5 rows of the dataset
iris_data.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# ### Viewing the entire dataset
# The Iris dataset has a total of  150 rows and 5 columns. To_string function was used to view the entire dataset. The measured attributes were sepal length, sepal width, petal length and width. The 3 species of iris flower in the dataset are setosa, versicolor and virginica.

# %%
# Viewing the total number of columns and rows
iris_data.shape
# Out:
# (150, 5)

# %%
# Scrolling through the entire dataset
print (iris_data.to_string())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...

# %%
# Printing off the unique species in the dataset.
iris_data['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# ## Data Structure
# There are four float (numeric) data type variables and one object (categorical) type.  None of all the 150 measured variables in the datset are of the non null type. There are 50 instances each for the setosa, versicolor and virginica.

# %%
# Viewing the data structure and types
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Checking and summng up the non.null variables
iris_data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# Counting the species in the dataset
iris_data['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
# Descriptives: Summary statistics of the numerical variables
iris_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_data.groupby('species').describe()
# Out:
#            sepal_length                                              \
#                   count   mean       std  min    25%  50%  75%  max
# species
# setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#            sepal_width         ... petal_length      petal_width         \
#                  count   mean  ...          75%  max       count   mean
# species                        ...
# setosa            50.0  3.428  ...        1.575  1.9        50.0  0.246
# versicolor        50.0  2.770  ...        4.600  5.1        50.0  1.326
# virginica         50.0  2.974  ...        5.875  6.9        50.0  2.026
#
#
#                  std  min  25%  50%  75%  max
# species
# setosa      0.105386  0.1  0.2  0.2  0.3  0.6
# versicolor  0.197753  1.0  1.2  1.3  1.5  1.8
# virginica   0.274650  1.4  1.8  2.0  2.3  2.5
#
# ...

# %% [markdown]
# ### Categorical Variables
# ##### Countplot

# %%
# Categorical Variables: Plotting the Countplot
sns.countplot(iris_data, x='species')
plt.title('Iris Dataset Species Countplot')
# Out:
# Text(0.5, 1.0, 'Iris Dataset Species Countplot')

# %% [markdown]
# ### Univariate Analysis

# %%
#creating a histogram for the numerical variables
fig, ax = plt.subplots(2, 2, figsize = (13, 8))
fig.suptitle ('Iris dataset numerical variable Histogram')

# Setting up the subplots
sns.histplot(data=iris_data, x='sepal_length', hue='species',  multiple='stack', kde=True, ax = ax [0, 0])
sns.histplot(data=iris_data, x='sepal_width', hue='species',   multiple='stack', kde=True, ax = ax [0, 1])
sns.histplot(data=iris_data, x='petal_length', hue='species',multiple='stack', kde=True, ax = ax [1, 0])
sns.histplot(data=iris_data, x='petal_width', hue='species', multiple='stack',kde=True, ax = ax [1, 1])
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
fig, ax = plt.subplots(2, 2, figsize = (15, 15))
fig.suptitle ('Iris Dataset numeric variables stripplots by species')

#creating chart for each subplot
sns.stripplot(data=iris_data, y='sepal_length', x ='species', hue ='species', ax = ax [0, 0])
sns.stripplot(data=iris_data, y='sepal_width',  x ='species', hue ='species', ax = ax [0, 1])
sns.stripplot(data=iris_data, y='petal_length', x ='species', hue ='species', ax = ax [1, 0])
sns.stripplot(data=iris_data, y='petal_width',  x ='species', hue ='species', ax = ax [1, 1])
# Out:
# <Axes: xlabel='species', ylabel='petal_width'>

# %% [markdown]
# Histogram summary by species

# %% [markdown]
# ## Data Cleaning and  Manipulation
# ### Data Quality Checks

# %%
# Creating a copy of the dataset before cleaning up the data
iris = iris_data.copy()
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# checking for missing values
iris.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# Checking for the total number of duplicates
iris.duplicated().sum()
# Out:
# 1

# %%
# Displaying the duplicate row
iris[iris.duplicated()]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 142           5.8          2.7           5.1          1.9  virginica

# %%
# Rechecking the value count per specie
iris['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# The species value count shows equal number of each specie (n = 50) as a result the duplicate values will be ignored because this may be due to 2 different iris virginica in the dataset coincidentally having the same measurements across board.

# %% [markdown]
# ### Outlier Mining
# The outlier test was used to detect values that differ significantly within the species subset in the iris dataset.
# These values were visualized with a Boxplot. In the boxplot, observations outside the whiskers are the outliers:
#
# $ (Q1 +/- 1.5 * iIQR)$.

# %% [markdown]
# #### Finding the Interquartile range by Iris Species

# %%
# Using pandas groupby to group the dataset by species
iris_species = iris.groupby('species')
print(iris_species.count()) #counting each specie
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa                50           50            50           50
# versicolor            50           50            50           50
# virginica             50           50            50           50

# %%
# Isolating the species in the dataset
setosa = iris_species.get_group('setosa')
versicolor = iris_species.get_group('versicolor')
virginica = iris_species.get_group('virginica')

# %%
# Selecting the numerical columns for each specie
setosa =iris_species.get_group('setosa').select_dtypes(include=['float64'])
versicolor =iris_species.get_group('versicolor').select_dtypes(include=['float64'])
virginica =iris_species.get_group('virginica').select_dtypes(include=['float64'])

# %%
# Defining a function to detect outliers by interquartile method
def IQR_outlier(df):
    Q1 = df.quantile(0.25)     # Finding the 25th percentile
    Q3 = df.quantile(0.75)     # Finding the 75th percentile
    IQR = Q3 - Q1              # Interquartile range
    lower_limit = Q1 - 1.5 * IQR   # defining the lower limit of the range
    upper_limit = Q3 + 1.5 * IQR   # defining the upper limit of the range
    outliers = df[((df<(lower_limit)) | (df>(upper_limit)))]
    return outliers

# %%
# finding outliers in the dataset by species 
outliers = iris_species.apply(IQR_outlier)

# Dropping rows where all the elements are not a number(NAN)
species_outliers = outliers.dropna(how='all')  
species_outliers
# Out:
#                 sepal_length  sepal_width  petal_length  petal_width
# species
# setosa     13            NaN          NaN           1.1          NaN
#            15            NaN          4.4           NaN          NaN
#            22            NaN          NaN           1.0          NaN
#            23            NaN          NaN           NaN          0.5
#            24            NaN          NaN           1.9          NaN
#            41            NaN          2.3           NaN          NaN
#            43            NaN          NaN           NaN          0.6
#            44            NaN          NaN           1.9          NaN
# versicolor 98            NaN          NaN           3.0          NaN
# virginica  106           4.9          NaN           NaN          NaN
#            117           NaN          3.8           NaN          NaN
#            119           NaN          2.2           NaN          NaN
# ...

# %% [markdown]
# ### Counting the outliers for each specie

# %%
# Isolating the setosa group and finding the outliers count 
setosa_outliers =  setosa.apply(IQR_outlier)
print (setosa_outliers.count())
# Out:
# sepal_length    0
# sepal_width     2
# petal_length    4
# petal_width     2
# dtype: int64

# %%
# Isolating the versicolor group and finding the outliers count 
versicolor_outliers =  iris_species.get_group('versicolor').select_dtypes(include=['float64']).apply(IQR_outlier)
print (versicolor_outliers.count())
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    1
# petal_width     0
# dtype: int64

# %%
# Isolating the viriginica group and finding the outliers count 
virginica_outliers =  iris_species.get_group('virginica').select_dtypes(include=['float64']).apply(IQR_outlier)
print (setosa_outliers.count())
# Out:
# sepal_length    0
# sepal_width     2
# petal_length    4
# petal_width     2
# dtype: int64

# %% [markdown]
# ## Using imputation to replace the outliers within each group

# %%
iris_clean = iris_species

# %% [markdown]
# Non outliers are represented as not a number

# %% [markdown]
# #### Visualizing Outliers
# ##### Boxplot
# Boxpolot was used to visualize the presnce of outliers

# %%
# Boxplot
fig, ax = plt.subplots(2, 2, figsize = (13, 8))
fig.suptitle ('Iris Dataset numerical variable Boxplots')

#creating chart for each subplot
#plot 1: row 1, column 1
sns.boxplot(data=iris, x='species', y='sepal_length', ax = ax [0, 0])

#plot 2: row 1, column 2
sns.boxplot(data=iris, x='species', y='sepal_width', ax = ax [0, 1])

#plot 3: row 2, column 1
sns.boxplot(data=iris, x='species', y='petal_length', ax = ax [1, 0])

#plot 4: row 2, column 2
sns.boxplot(data=iris, x='species', y='petal_width', ax = ax [1, 1])
# Out:
# <Axes: xlabel='species', ylabel='petal_width'>

# %%
# Removing the outliers from the boxplot
fig, ax = plt.subplots(2, 2, figsize = (13, 8))
fig.suptitle ('Iris Dataset numerical variable Boxplots')

#creating chart for each subplot
#plot 1: row 1, column 1
sns.boxplot(data=iris, x='species', y='sepal_length', showfliers=False, ax = ax [0, 0])

#plot 2: row 1, column 2
sns.boxplot(data=iris, x='species', y='sepal_width', showfliers=False, ax = ax [0, 1])

#plot 3: row 2, column 1
sns.boxplot(data=iris, x='species', y='petal_length', showfliers=False, ax = ax [1, 0])

#plot 4: row 2, column 2
sns.boxplot(data=iris, x='species', y='petal_width', showfliers=False, ax = ax [1, 1])
# Out:
# <Axes: xlabel='species', ylabel='petal_width'>

# %% [markdown]
# ## Outliers summary

# %% [markdown]
# ## Bivariate Analysis
# The [Seaborn pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html) was used to visualise the pairwise relationship between variables.

# %%
# creating a pairplot of the  iris dataset
sns.pairplot(iris, hue = 'species', markers= ['o', 's','^'], height=3.5, aspect=1.02)

# Creating the main title for the pairplot
plt.suptitle('Pairplot of the Iris datset')

# Suppressing the figure layout warning to make it tidy
warnings.filterwarnings('ignore', message='The figure layout has changed to tight')
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Correlation Analysis

# %%
# Selecting the numeric columns from the DataFrame
iris_numeric = iris.select_dtypes(include=['float64'])

# Calculating the correlation matrix of the numeric variables
iris_numeric_corr = iris_numeric.corr()
print (iris_numeric_corr)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
# Creating the heatmap with the correlation matrix 
sns.heatmap(iris_numeric_corr, annot=True, cmap='coolwarm')

# labelling the title
plt.title('Iris Dataset numeric variables Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Iris Dataset numeric variables Correlation Matrix')

# %%
#printing off variables with strong correlation
iris_numeric_corr = iris_numeric_corr.unstack()
#abs to convert neg corr to pos corr
strong_corr =iris_numeric_corr[abs(iris_numeric_corr) >= 0.7]   
print (strong_corr)
# Out:
# sepal_length  sepal_length    1.000000
#               petal_length    0.871754
#               petal_width     0.817941
# sepal_width   sepal_width     1.000000
# petal_length  sepal_length    0.871754
#               petal_length    1.000000
#               petal_width     0.962865
# petal_width   sepal_length    0.817941
#               petal_length    0.962865
#               petal_width     1.000000
# dtype: float64

# %% [markdown]
# strong correlation between petal length and petal width
# petal length and sepal length

# %% [markdown]
# #### Regression Analysis
# The linear relationship between two variables x and y can be can be calculated using the formula;
#
# $y = mx + c$
#
# Where m = slope
#
# c = intercept
#
# However, this can be achieved in numpy with the formula;
#
# $ y = mx + c = p_1x^1 + p_o = p_1 x + po$

# %%
Plen = iris['petal_length']
Pwidth = iris['petal_width']
Slen = iris['sepal_length']
Swidth = iris['sepal_width']

# %%
# creating the scatterplot of petal length and petal width
sns.scatterplot(data=iris, x='petal_length', y='petal_width', hue='species')

plt.title ('Scatterplot of iris petal length and petal width')

#calculating the correlation coefficient
plen_pwidth_corr  = iris['petal_length'].corr(iris['petal_width'])
print (plen_pwidth_corr)

# calculating the slope(m) and intercept (c)
m, c = np.polyfit(Plen, Pwidth, deg=1) # deg = 1 for lin reg

#show
print (f'The slope is {m} and the intercept is {c}')

#creating the best fit line for petal length using its min and max values to gen 100 equally spaced values
Plen_values = np.linspace(min(Plen), max(Plen), 100)

# generating the corresponding values for the petal width
Pwidth_values = m * Plen_values + c

# plotting the best fit line for bodymass vs flipper length
plt.plot(Plen_values, Pwidth_values, color='black')
# Out:
# 0.9628654314027961
# The slope is 0.4157554163524116 and the intercept is -0.3630755213190288

# %% [markdown]
# #### Regression Slope
# The slope was calculated to be 0.4157554163524116 and the intercept -0.3630755213190288. The iris petal width was the dependent variable and the petal length the independent variable. If every other variable should remain constant, for a millimeter increase in the iris petal length there is an expected increase in the iris petal width of about 0.42 mm.

# %%
# Regression pairplot
sns.pairplot(data=iris, x_vars='petal_length', y_vars='petal_width', hue='species', height=6, aspect=1.02, kind='reg')
plt.title('Relationship between ris petal length and petal width')
# Out:
# Text(0.5, 1.0, 'Relationship between ris petal length and petal width')

# %%
sepLen = slen.to_numpy()
print (sepLen)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 sepLen = slen.to_numpy()
#       2 print (sepLen)
#
# NameError: name 'slen' is not defined

# %%
sepWidth = swidth.to_numpy()
print (sepWidth)
# Out:
# [3.5 3.  3.2 3.1 3.6 3.9 3.4 3.4 2.9 3.1 3.7 3.4 3.  3.  4.  4.4 3.9 3.5
#  3.8 3.8 3.4 3.7 3.6 3.3 3.4 3.  3.4 3.5 3.4 3.2 3.1 3.4 4.1 4.2 3.1 3.2
#  3.5 3.6 3.  3.4 3.5 2.3 3.2 3.5 3.8 3.  3.8 3.2 3.7 3.3 3.2 3.2 3.1 2.3
#  2.8 2.8 3.3 2.4 2.9 2.7 2.  3.  2.2 2.9 2.9 3.1 3.  2.7 2.2 2.5 3.2 2.8
#  2.5 2.8 2.9 3.  2.8 3.  2.9 2.6 2.4 2.4 2.7 2.7 3.  3.4 3.1 2.3 3.  2.5
#  2.6 3.  2.6 2.3 2.7 3.  2.9 2.9 2.5 2.8 3.3 2.7 3.  2.9 3.  3.  2.5 2.9
#  2.5 3.6 3.2 2.7 3.  2.5 2.8 3.2 3.  3.8 2.6 2.2 3.2 2.8 2.8 2.7 3.3 3.2
#  2.8 3.  2.8 3.  2.8 3.8 2.8 2.8 2.6 3.  3.4 3.1 3.  3.1 3.1 3.1 2.7 3.2
#  3.3 3.  2.5 3.  3.4 3. ]

# %%
#stateless
fig, ax = plt.subplots()
ax.plot(sepLen, sepWidth, 'x')
ax.set_xlabel('sepal width (cm)')
ax.set_ylabel('sepal length (cm)')
ax.set_title('Iris data set')
#setting the axis limit
#x limit
#ax.set_xlim(0, 8)
#y limits
#ax.set_ylim(20, 65)
#add best fit line
# Out:
# Text(0.5, 1.0, 'Iris data set')

# %% [markdown]
# #$ is used at the beginning and at the end of the equation  to render it in mathematical equation
# #y = mx + c is used to find the linear relationsship btw x and y while m and c ae constant
#
# $ y = mx + c = p_1x^1 + p_o = p_1 x + po $

# %%
m, c = np.polyfit (sepLen, sepWidth, 1)

#show m and c
#m, c

# %%
#getting the correlation coefficient between the sepal lengt and sepal width
np.corrcoef(sepLen, sepWidth)
#laered website for correlation coefficient
# Out:
# array([[ 1.        , -0.11756978],
#        [-0.11756978,  1.        ]])

# %%
#x values for best fit line
bf_x = np.linspace(0.0, sepLen.max() + 1, 100)

#y values for best fit line
bf_y = m * bf_x + c

#show
bf_x, bf_y
# Out:
# (array([0.        , 0.08989899, 0.17979798, 0.26969697, 0.35959596,
#         0.44949495, 0.53939394, 0.62929293, 0.71919192, 0.80909091,
#         0.8989899 , 0.98888889, 1.07878788, 1.16868687, 1.25858586,
#         1.34848485, 1.43838384, 1.52828283, 1.61818182, 1.70808081,
#         1.7979798 , 1.88787879, 1.97777778, 2.06767677, 2.15757576,
#         2.24747475, 2.33737374, 2.42727273, 2.51717172, 2.60707071,
#         2.6969697 , 2.78686869, 2.87676768, 2.96666667, 3.05656566,
#         3.14646465, 3.23636364, 3.32626263, 3.41616162, 3.50606061,
#         3.5959596 , 3.68585859, 3.77575758, 3.86565657, 3.95555556,
#         4.04545455, 4.13535354, 4.22525253, 4.31515152, 4.40505051,
#         4.49494949, 4.58484848, 4.67474747, 4.76464646, 4.85454545,
#         4.94444444, 5.03434343, 5.12424242, 5.21414141, 5.3040404 ,
#         5.39393939, 5.48383838, 5.57373737, 5.66363636, 5.75353535,
#         5.84343434, 5.93333333, 6.02323232, 6.11313131, 6.2030303 ,
# ...
